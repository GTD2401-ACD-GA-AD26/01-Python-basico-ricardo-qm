# %% [markdown]
# # Aritmética y Variables
#
# En este JNB se revisará el tema de Aritmética y Variables

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print(1+2)
# Out:
# 3

# %%
1+2
# Out:
# 3

# %%
print(9 - 5)
# Out:
# 4

# %%
print(((1 + 3) * (9 - 2) / 2) ** 2)
# Out:
# 196.0

# %%
# Multiply 3 by 2
print(3 * 2)
# Out:
# 6

# %% [markdown]
# # Trabajando con variables
#
# En Python las variables se crean al momento de inicializarlas y no es necesario declarar su tipo de dato. Por ejemplo:
#
# ```python
# # Inicializando variables
# x = 5
# y = 10
# # Realizando operaciones aritméticas
# suma = x + y
# resta = x - y
# multiplicacion = x * y
# division = x / y
# # Mostrando resultados
# print("Suma:", suma)
# print("Resta:", resta)

# %%
# Create a variable called test_var and give it a value of 4+5
test_var = 4 + 5

# Print the value of test_var
print(test_var)
# Out:
# 9

# %%
type(test_var)
# Out:
# int

# %%
# Set the value of a new variable to 3
my_var = 3

# Print the value assigned to my_var
print(my_var)

# Change the value of the variable to 100
my_var = 100

# Print the new value assigned to my_var
print(my_var)
# Out:
# 3
# 100

# %%
print(my_var)
print(test_var)
# Out:
# 100
# 9

# %%
# Increase the value by 3
my_var = my_var + 3

# Print the value assigned to my_var
print(my_var)
# Out:
# 103

# %%
# Create variables
num_years = 4
days_per_year = 365 
hours_per_day = 24
mins_per_hour = 60
secs_per_min = 60

# Calculate number of seconds in four years
total_secs = secs_per_min * mins_per_hour * hours_per_day * days_per_year * num_years
print(total_secs)
# Out:
# 126144000

# %%
nombre=input("¿Cuál es tu nombre? ")

print("Hola " + nombre + ", bienvenido a la clase de Python básico.")
# Out:
# Hola Ricardo, bienvenido a la clase de Python básico.

# %%
edad = int(input("¿Cuál es tu edad? "))
print("Tienes", edad, "años.")
# Out:
# Tienes 45 años.

# %%
type(edad)
