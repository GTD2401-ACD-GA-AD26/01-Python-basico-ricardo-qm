# %% [markdown]
# # Aritmética y Variables
#
# En este JNB se revisará el tema de Aritmética y Variables

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print(1+2)
# Out:
# 3

# %%
1+2
# Out:
# 3

# %%
print(9 - 5)
# Out:
# 4

# %%
print(((1 + 3) * (9 - 2) / 2) ** 2)
# Out:
# 196.0

# %%
# Multiply 3 by 2
print(3 * 2)
# Out:
# 6
